# %% [markdown]
# Usaremos una base de datos de imágenes con dos clases: perros y gatos.
#
# El objetivo es diseñar redes neuronales de convolución para clasificar perros
# de gatos. Este problema es mucho más complejo que los anteriores, ya que:
#
# 1. la cantidad de características visuales que comparten perros y gatos pueden
# ser altas
# 2. las imágenes pueden contener background común. Estas dos
# características hace difícil separa las imágenes.
#
# También probaremos una función de utilidad de tensorflow, con la cual no
# necesitamos cargar todos los datos en memoria al mismo tiempo, sino que los
# vamos cargando por lote (al vuelo). Con la ventaja adicional de que podemos
# crear variaciones sintéticas de ellos.
#
# Finalmente, veremos otras dos aplicaciones de CNN's

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, UpSampling2D, Conv2DTranspose
from tensorflow.keras.layers import BatchNormalization, Dropout, LeakyReLU
from tensorflow.keras.layers import Dense, Flatten, Concatenate
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD

from sklearn.model_selection import train_test_split

# %% [markdown]
# # Part 1: Download data and set directories

# %%
# Download data from a website
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
path_to_zip = tf.keras.utils.get_file('cats_and_dogs.zip', origin=_URL, extract=True)
PATH = os.path.join(os.path.dirname(path_to_zip), 'cats_and_dogs_filtered')

# List path contents
# !ls $PATH
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68606236/68606236 [==============================] - 2s 0us/step
# train  validation  vectorize.py

# %%
# Define paths to training and validation images
train_dir = os.path.join(PATH, 'train')
val_dir = os.path.join(PATH, 'validation')

# Specify them by class
train_cats_dir = os.path.join(train_dir, 'cats')  # directory with training cat pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')  # directory with training dog pictures
val_cats_dir = os.path.join(val_dir, 'cats')      # directory with validation cat pictures
val_dogs_dir = os.path.join(val_dir, 'dogs')      # directory with validation dog pictures

# Print example
print(train_cats_dir)
# Out:
# /root/.keras/datasets/cats_and_dogs_filtered/train/cats

# %%
# Count how many of them are there
n_cats_train = len(os.listdir(train_cats_dir))
n_dogs_train = len(os.listdir(train_dogs_dir))

n_cats_val = len(os.listdir(val_cats_dir))
n_dogs_val = len(os.listdir(val_dogs_dir))

n_total_train = n_cats_train + n_dogs_train
n_total_val = n_cats_val + n_dogs_val

# Print some info
print('total training cat images:', n_cats_train)
print('total training dog images:', n_dogs_train)

print('total validation cat images:', n_cats_val)
print('total validation dog images:', n_dogs_val)
print("--")
print("Total training images:", n_total_train)
print("Total validation images:", n_total_val)
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# --
# Total training images: 2000
# Total validation images: 1000

# %% [markdown]
# # Part 2: Define data generators

# %%
# Define some constants
batch_size = 64
IMG_H = 128
IMG_W = 128

# %%
# Define generator objects for training and validation data.
# Generator objects will include controlled noise

# With added noise
train_datagen = ImageDataGenerator(rescale=1./255, rotation_range=5,
                                   width_shift_range=0.10, height_shift_range=0.10,
                                   shear_range=0.10, zoom_range=0.10, horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255, rotation_range=5,
                                 width_shift_range=0.10, height_shift_range=0.10,
                                 shear_range=0.10, zoom_range=0.10,  horizontal_flip=True)

# Without noise (rescale is still need it, as pixel values have integer values
# between 0 and 255. after rescaling them, they have real values between 0 and 1).
#train_datagen = ImageDataGenerator(rescale=1./255)
#val_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Define method to load images from disk, apply rescaling, and resize them into specified size.
train_generator = train_datagen.flow_from_directory(batch_size=batch_size,
                                                directory=train_dir,
                                                shuffle=True,
                                                target_size=(IMG_H, IMG_W),
                                                class_mode='binary')
val_generator = val_datagen.flow_from_directory(batch_size=batch_size,
                                            directory=val_dir,
                                            target_size=(IMG_H, IMG_W),
                                            class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
# This cell is just an example of a batch returned by the data generator
# The 'next()' function returns a batch from the dataset
sample_x, sample_y = next(train_generator)
print(sample_x.shape)
print(sample_x.min())
print(sample_x.max())
print(sample_y.shape)

# Show a few of them
fig, axes = plt.subplots(1, 10, figsize=(18, 5))
axes = axes.flatten()
for ind, (img, ax) in enumerate(zip(sample_x[:10], axes)):
  ax.imshow(img)
  ax.set_title("Class:" + str(int(sample_y[ind])))
  ax.axis('off')
plt.tight_layout()
plt.show()
# Out:
# (64, 128, 128, 3)
# 0.0
# 1.0
# (64,)

# %% [markdown]
# # Part 3: Create CNN model and train it

# %% [markdown]
# ### == Q1 ==
# Diseña una red CNN:
# - ¿Puedes lograr exactitud >= 0.8 en el set de validación?
# - ¿Cuál es la pérdida asociada?
# - ¿Cuántos parámetros tiene tu modelo?
# - ¿Qué otros hiper-parámetros definiste?

# %%
# Create a CNN
CNN = Sequential([
    Input(shape=(IMG_H, IMG_W, 3)),
    
    Conv2D(filters=32, kernel_size=3, padding='same'),
    LeakyReLU(),
    Conv2D(filters=32, kernel_size=1, padding='same'),
    LeakyReLU(),
    MaxPool2D(),

    Conv2D(filters=64, kernel_size=3, padding='same'),
    LeakyReLU(),
    Conv2D(filters=64, kernel_size=1, padding='same'),
    LeakyReLU(),
    MaxPool2D(),

    Conv2D(filters=128, kernel_size=3, padding='same'),
    LeakyReLU(),
    Conv2D(filters=128, kernel_size=1, padding='same'),
    LeakyReLU(),
    MaxPool2D(),

    Conv2D(filters=256, kernel_size=3, padding='same'),
    LeakyReLU(),
    Conv2D(filters=256, kernel_size=1, padding='same'),
    LeakyReLU(),
    MaxPool2D(),

    Flatten(),
    Dense(128, activation='relu'),
    Dense(1, activation='sigmoid')
])

CNN.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_32 (Conv2D)          (None, 128, 128, 32)      896
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 128, 128, 32)      0
#
#  conv2d_33 (Conv2D)          (None, 128, 128, 32)      1056
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 128, 128, 32)      0
#
#  max_pooling2d_12 (MaxPoolin  (None, 64, 64, 32)       0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 64, 64, 64)        18496
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 64, 64, 64)        0
#
#  conv2d_35 (Conv2D)          (None, 64, 64, 64)        4160
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 64, 64, 64)        0
#
#  max_pooling2d_13 (MaxPoolin  (None, 32, 32, 64)       0
#  g2D)
#
#  conv2d_36 (Conv2D)          (None, 32, 32, 128)       73856
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 32, 32, 128)       0
#
#  conv2d_37 (Conv2D)          (None, 32, 32, 128)       16512
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 32, 32, 128)       0
#
#  max_pooling2d_14 (MaxPoolin  (None, 16, 16, 128)      0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 16, 16, 256)       295168
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 16, 16, 256)       0
#
#  conv2d_39 (Conv2D)          (None, 16, 16, 256)       65792
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 16, 16, 256)       0
#
#  max_pooling2d_15 (MaxPoolin  (None, 8, 8, 256)        0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 16384)             0
#
#  dense_6 (Dense)             (None, 128)               2097280
#
#  dense_7 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 2,573,345
# Trainable params: 2,573,345
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile: Define training parameters
optim = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
CNN.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train model
EPOCHS = 50
BATCHES = n_total_train//batch_size

CNN.fit(train_generator, steps_per_epoch=BATCHES, epochs=EPOCHS, validation_data=val_generator)
# Out:
# Epoch 1/50
# 31/31 [==============================] - 22s 628ms/step - loss: 0.6981 - accuracy: 0.4923 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch

plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.title('Accuracy')
plt.plot(CNN.history.history['accuracy'], label='Training', linewidth=2)
plt.plot(CNN.history.history['val_accuracy'], label='Validation', linewidth=2)
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)

plt.show()

# %% [markdown]
# # Part 4: Images as vectors

# %%
# Define generators
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Define method to load images from disk, apply rescaling, and resize them into specified size.
train_generator = train_datagen.flow_from_directory(batch_size=batch_size,
                                                directory=train_dir,
                                                shuffle=True,
                                                target_size=(IMG_H, IMG_W),
                                                class_mode='binary')
val_generator = val_datagen.flow_from_directory(batch_size=batch_size,
                                            directory=val_dir,
                                            target_size=(IMG_H, IMG_W),
                                            class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
# Get a batch sample, just to see its shape
sample_x, sample_y = next(train_generator)
print(sample_x.shape)
print(sample_x.min())
print(sample_x.max())
print(sample_y.shape)

sample_x = np.reshape(sample_x, newshape=(len(sample_x), -1))
print(sample_x.shape)
print(sample_x.min())
print(sample_x.max())
print(sample_y.shape)
# Out:
# (64, 128, 128, 3)
# 0.0
# 1.0
# (64,)
# (64, 49152)
# 0.0
# 1.0
# (64,)

# %%
# == Q2 ==
# Create MLP (only perceptrons) and repeat training
# Try to get your MLP with as many parameters as your best previous CNN
# ¿Puedes lograr exactitud >= 0.8 en el set de validación?
# ¿Cuál es la pérdida asociada?
# ¿Cuántos parámetros tiene tu modelo?
# ¿Qué otros hiper-parámetros definiste?

DNN = Sequential([
    Input(shape=(49152,)),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

DNN.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_17 (Dense)            (None, 512)               25166336
#
#  dense_18 (Dense)            (None, 256)               131328
#
#  dense_19 (Dense)            (None, 128)               32896
#
#  dense_20 (Dense)            (None, 64)                8256
#
#  dense_21 (Dense)            (None, 32)                2080
#
#  dense_22 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 25,340,929
# Trainable params: 25,340,929
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile: Define training parameters
DNN.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Training code, step by step
EPOCHS = 50
BATCHES = n_total_train//batch_size
for e in range(EPOCHS):
  print(f'Epoch: {e+1:2d}', end='[')
  for batch in range(BATCHES):
    x_batch, y_batch = next(train_generator)
    x_batch = np.reshape(x_batch, newshape=(len(x_batch), -1))
    DNN.fit(x_batch, y_batch, verbose=0)
    print('=', end='')

  # At the end of the epoch, evaluate and print performance
  # on training batch
  x_batch, y_batch = next(train_generator)
  x_batch = np.reshape(x_batch, newshape=(len(x_batch), -1))
  loss, accuracy = DNN.evaluate(x_batch, y_batch, verbose=0)
  # on validation batch
  x_val_batch, y_val_batch = next(val_generator)
  x_val_batch = np.reshape(x_val_batch, newshape=(len(x_val_batch), -1))
  val_loss, val_accuracy = DNN.evaluate(x_val_batch, y_val_batch, verbose=0)
  # print
  print(f"] - loss: {loss:.4f} - accuracy: {accuracy:.4f} - val_loss: {val_loss:.4f} - val_accuracy: {val_accuracy:.4f}")
# Out:
# Epoch:  1[===============================] - loss: 0.8876 - accuracy: 0.5000 - val_loss: 0.8031 - val_accuracy: 0.5625
# Epoch:  2[===============================] - loss: 0.9355 - accuracy: 0.4688 - val_loss: 0.7845 - val_accuracy: 0.6000
# Epoch:  3[===============================] - loss: 0.6799 - accuracy: 0.5625 - val_loss: 0.7669 - val_accuracy: 0.5156
# Epoch:  4[===============================] - loss: 0.6869 - accuracy: 0.5625 - val_loss: 0.6844 - val_accuracy: 0.5312
# Epoch: 30[===============================] - loss: 0.4314 - accuracy: 0.8281 - val_loss: 0.5656 - val_accuracy: 0.7188
# Epoch: 31[===============================] - loss: 0.4961 - accuracy: 0.7344 - val_loss: 0.8267 - val_accuracy: 0.5312
# Epoch: 32[===============================] - loss: 0.4264 - accuracy: 0.7188 - val_loss: 0.8481 - val_accuracy: 0.6094
# Epoch: 33[===============================] - loss: 0.5477 - accuracy: 0.7188 - val_loss: 0.7741 - val_accuracy: 0.4375
# Epoch: 34[===============================] - loss: 0.5333 - accuracy: 0.6875 - val_loss: 0.8331 - val_accuracy: 0.6750
# Epoch: 35[===============================] - loss: 0.6211 - accuracy: 0.5781 - val_loss: 0.8093 - val_accuracy: 0.4844
# Epoch: 36[===============================] - loss: 0.5841 - accuracy: 0.7188 - val_loss: 0.7237 - val_accuracy: 0.4688
# Epoch: 37[===============================] - loss: 0.4256 - accuracy: 0.7344 - val_loss: 0.9699 - val_accuracy: 0.5781
# Epoch: 38[===============================] - loss: 0.6891 - accuracy: 0.6875 - val_loss: 1.1880 - val_accuracy: 0.5938
# Epoch: 39[===============================] - loss: 0.3532 - accuracy: 0.9219 - val_loss: 0.7636 - val_accuracy: 0.5781
# Epoch: 40[===============================] - loss: 0.4877 - accuracy: 0.7812 - val_loss: 1.1044 - val_accuracy: 0.5156
# Epoch: 41[===============================] - loss: 0.3710 - accuracy: 0.8281 - val_loss: 0.7724 - val_accuracy: 0.6250
# Epoch: 42[===============================] - loss: 0.3759 - accuracy: 0.8281 - val_loss: 0.5442 - val_accuracy: 0.7500
# Epoch: 43[===============================] - loss: 0.3818 - accuracy: 0.8438 - val_loss: 1.3051 - val_accuracy: 0.5312
# Epoch: 44[===============================] - loss: 0.2364 - accuracy: 0.9531 - val_loss: 0.9952 - val_accuracy: 0.5156
# Epoch: 45[===============================] - loss: 0.2187 - accuracy: 0.9219 - val_loss: 1.2373 - val_accuracy: 0.5469
# Epoch: 46[===============================] - loss: 0.5888 - accuracy: 0.7500 - val_loss: 0.7001 - val_accuracy: 0.5625
# Epoch: 47[===============================] - loss: 0.3931 - accuracy: 0.8125 - val_loss: 1.1456 - val_accuracy: 0.4844
# Epoch: 48[===============================] - loss: 0.4516 - accuracy: 0.7656 - val_loss: 0.9757 - val_accuracy: 0.6250
# Epoch: 49[===============================] - loss: 0.2798 - accuracy: 0.9219 - val_loss: 0.9005 - val_accuracy: 0.6250
# Epoch: 50[===============================] - loss: 0.4105 - accuracy: 0.8594 - val_loss: 0.6354 - val_accuracy: 0.6500

# %% [markdown]
# # Part 5: A new type of CNN

# %%
from os import listdir
from os.path import join
from skimage.io import imread
from skimage.transform import resize

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Locate folder with dataset and check for existance of both dirs
# !ls /content/drive/MyDrive/DataSets/LFW/
# Out:
# images	masks

# %%
# Set paths to load images and masks
images_path = "/content/drive/MyDrive/DataSets/LFW/images/"
masks_path = "/content/drive/MyDrive/DataSets/LFW/masks/"

# %%
# Load images
image_names = [f for f in listdir(images_path)]
X = np.array([resize(imread(join(images_path, f)), (128, 128)) for f in image_names])

print(X.shape)
print(X.min())
print(X.max())
# Out:
# (1000, 128, 128, 3)
# 0.0
# 1.0

# %%
# Load masks
# (Uso los mismos nombres de archivos que para las imágenes, solo cambio el
# directorio y la extension)
Y = np.array([resize(imread(join(masks_path, f[:-3]+'ppm')), (128, 128)) for f in image_names])

print(Y.shape)
print(Y.min())
print(Y.max())
# Out:
# (1000, 128, 128, 3)
# 0.0
# 1.0

# %%
# Show a few examples
print("Images")
plt.figure(figsize=(18, 3))
for ind, img in enumerate(X[:10]):
  plt.subplot(1, 10, ind+1)
  plt.imshow(img)
  plt.axis('off')
plt.show()

print("Masks")
plt.figure(figsize=(18, 3))
for ind, img in enumerate(Y[:10]):
  plt.subplot(1, 10, ind+1)
  plt.imshow(img)
  plt.axis('off')
plt.show()
# Out:
# Images
# Masks

# %%
# Split train and test sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.1)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (900, 128, 128, 3)
# (900, 128, 128, 3)
# (100, 128, 128, 3)
# (100, 128, 128, 3)

# %%
# == Q3 ==
# Considera la siguiente CNN's
# ¿Por qué tiene 3 filtros convolucionales en el último layer?
# Revisa la documentación de tensorflow. ¿cuál es la diferencia entre el layer
# Conv2D y Con2DTranspose?
# ¿Puedes lograr exactitud >= 0.93 en el set de validación?
# ¿Cuál es la pérdida asociada?
# ¿Cuántos parámetros tiene tu modelo?
# ¿Qué otros hiper-parámetros definiste?

# %%
# # Lets create a CNN of type UNet
in_layer = Input(shape=(128, 128, 3))

conv1 = Conv2D(64, 3, padding='same', activation='relu')(in_layer)
conv1 = Conv2D(64, 3, padding='same', strides=2, activation='relu')(conv1)

conv2 = Conv2D(128, 3, padding='same', activation='relu')(conv1)
conv2 = Conv2D(128, 3, padding='same', strides=2, activation='relu')(conv2)

conv3 = Conv2D(256, 3, padding='same', activation='relu')(conv2)
conv3 = Conv2D(256, 3, padding='same', strides=2, activation='relu')(conv3)

conv4 = Conv2D(512, 3, padding='same', activation='relu')(conv3)

conc5 = Concatenate(axis=3)([conv4, conv3])
conv5 = Conv2DTranspose(256, 3, padding='same', strides=2, activation='relu')(conc5)
conv5 = Conv2D(256, 3, padding='same', activation='relu')(conv5)
# Conv2Transpose puede ser reemplazado por Conv2D + UpSampling2D

conc6 = Concatenate(axis=3)([conv5, conv2])
conv6 = Conv2DTranspose(128, 3, padding='same', strides=2, activation='relu')(conc6)
conv6 = Conv2D(128, 3, padding='same', activation='relu')(conv6)

conc7 = Concatenate(axis=3)([conv6, conv1])
conv7 = Conv2DTranspose(64, 3, padding='same', strides=2, activation='relu')(conc7)
conv7 = Conv2D(64, 3, padding='same', activation='relu')(conv7)

out_layer = Conv2D(3, 5, padding='same', activation='sigmoid')(conv7)

UNet = Model(in_layer, out_layer)
UNet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 64  1792        ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 64)   36928       ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 128)  73856       ['conv2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 128)  147584      ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 256)  295168      ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 256)  590080      ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 512)  1180160     ['conv2d_5[0][0]']
#
#  concatenate (Concatenate)      (None, 16, 16, 768)  0           ['conv2d_6[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 256)  1769728    ['concatenate[0][0]']
#  ose)
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  590080      ['conv2d_transpose[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 384)  0           ['conv2d_7[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 128)  442496     ['concatenate_1[0][0]']
#  spose)
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 128)  147584      ['conv2d_transpose_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 192)  0           ['conv2d_8[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 64  110656     ['concatenate_2[0][0]']
#  spose)                         )
#
#  conv2d_9 (Conv2D)              (None, 128, 128, 64  36928       ['conv2d_transpose_2[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 3)  4803        ['conv2d_9[0][0]']
#
# ==================================================================================================
# Total params: 5,427,843
# Trainable params: 5,427,843
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(UNet, to_file='model.png', show_shapes=True, show_layer_names=True, dpi=48)

# %%
# Compile and train it
UNet.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
UNet.fit(x_train, y_train, batch_size=64, epochs=30, validation_split=0.2)
# Out:
# Epoch 1/30
# 12/12 [==============================] - 30s 1s/step - loss: 0.6645 - accuracy: 0.6165 - val_loss: 0.5894 - val_accuracy: 0.6675
# Epoch 2/30
# 12/12 [==============================] - 6s 480ms/step - loss: 0.5327 - accuracy: 0.6618 - val_loss: 0.4530 - val_accuracy: 0.6678
# Epoch 3/30
# 12/12 [==============================] - 6s 484ms/step - loss: 0.4361 - accuracy: 0.6621 - val_loss: 0.4028 - val_accuracy: 0.6678
# Epoch 4/30
# 12/12 [==============================] - 6s 483ms/step - loss: 0.3920 - accuracy: 0.6624 - val_loss: 0.3614 - val_accuracy: 0.7701
# Epoch 5/30
# 12/12 [==============================] - 6s 486ms/step - loss: 0.3350 - accuracy: 0.7844 - val_loss: 0.2818 - val_accuracy: 0.8193
# Epoch 6/30
# 12/12 [==============================] - 6s 487ms/step - loss: 0.2880 - accuracy: 0.8085 - val_loss: 0.2536 - val_accuracy: 0.8484
# Epoch 7/30
# 12/12 [==============================] - 6s 496ms/step - loss: 0.2537 - accuracy: 0.8446 - val_loss: 0.2542 - val_accuracy: 0.8444
# Epoch 8/30
# 12/12 [==============================] - 6s 506ms/step - loss: 0.2512 - accuracy: 0.8473 - val_loss: 0.2206 - val_accuracy: 0.8718
# Epoch 9/30
# 12/12 [==============================] - 6s 496ms/step - loss: 0.2228 - accuracy: 0.8659 - val_loss: 0.2082 - val_accuracy: 0.8762
# Epoch 10/30
# 12/12 [==============================] - 6s 496ms/step - loss: 0.2087 - accuracy: 0.8739 - val_loss: 0.2084 - val_accuracy: 0.8798
# Epoch 11/30
# 12/12 [==============================] - 6s 498ms/step - loss: 0.2058 - accuracy: 0.8766 - val_loss: 0.1924 - val_accuracy: 0.8860
# Epoch 12/30
# 12/12 [==============================] - 6s 502ms/step - loss: 0.1927 - accuracy: 0.8831 - val_loss: 0.1877 - val_accuracy: 0.8870
# Epoch 13/30
# 12/12 [==============================] - 6s 502ms/step - loss: 0.1884 - accuracy: 0.8864 - val_loss: 0.1805 - val_accuracy: 0.8912
# Epoch 14/30
# 12/12 [==============================] - 6s 503ms/step - loss: 0.1831 - accuracy: 0.8887 - val_loss: 0.1837 - val_accuracy: 0.8889
# Epoch 15/30
# 12/12 [==============================] - 6s 502ms/step - loss: 0.1795 - accuracy: 0.8918 - val_loss: 0.1767 - val_accuracy: 0.8938
# Epoch 16/30
# 12/12 [==============================] - 6s 504ms/step - loss: 0.1775 - accuracy: 0.8942 - val_loss: 0.1734 - val_accuracy: 0.8947
# Epoch 17/30
# 12/12 [==============================] - 6s 505ms/step - loss: 0.1765 - accuracy: 0.8932 - val_loss: 0.1669 - val_accuracy: 0.9000
# Epoch 18/30
# 12/12 [==============================] - 6s 506ms/step - loss: 0.1766 - accuracy: 0.8952 - val_loss: 0.1750 - val_accuracy: 0.8948
# Epoch 19/30
# 12/12 [==============================] - 6s 508ms/step - loss: 0.1687 - accuracy: 0.8983 - val_loss: 0.1771 - val_accuracy: 0.8908
# Epoch 20/30
# 12/12 [==============================] - 6s 509ms/step - loss: 0.1678 - accuracy: 0.8984 - val_loss: 0.2095 - val_accuracy: 0.8700
# Epoch 21/30
# 12/12 [==============================] - 6s 511ms/step - loss: 0.1783 - accuracy: 0.8915 - val_loss: 0.1640 - val_accuracy: 0.9012
# Epoch 22/30
# 12/12 [==============================] - 6s 512ms/step - loss: 0.1626 - accuracy: 0.9026 - val_loss: 0.1852 - val_accuracy: 0.8881
# Epoch 23/30
# 12/12 [==============================] - 6s 513ms/step - loss: 0.1677 - accuracy: 0.8993 - val_loss: 0.1648 - val_accuracy: 0.9013
# Epoch 24/30
# 12/12 [==============================] - 6s 516ms/step - loss: 0.1620 - accuracy: 0.9029 - val_loss: 0.1595 - val_accuracy: 0.9033
# Epoch 25/30
# 12/12 [==============================] - 6s 518ms/step - loss: 0.1556 - accuracy: 0.9063 - val_loss: 0.1592 - val_accuracy: 0.9045
# Epoch 26/30
# 12/12 [==============================] - 6s 518ms/step - loss: 0.1519 - accuracy: 0.9093 - val_loss: 0.1542 - val_accuracy: 0.9077
# Epoch 27/30
# 12/12 [==============================] - 6s 519ms/step - loss: 0.1482 - accuracy: 0.9114 - val_loss: 0.1471 - val_accuracy: 0.9105
# Epoch 28/30
# 12/12 [==============================] - 6s 520ms/step - loss: 0.1423 - accuracy: 0.9146 - val_loss: 0.1572 - val_accuracy: 0.9075
# Epoch 29/30
# 12/12 [==============================] - 6s 523ms/step - loss: 0.1425 - accuracy: 0.9140 - val_loss: 0.1545 - val_accuracy: 0.9062
# Epoch 30/30
# 12/12 [==============================] - 6s 521ms/step - loss: 0.1408 - accuracy: 0.9152 - val_loss: 0.1470 - val_accuracy: 0.9129

# %%
# Evaluate on test set
UNet.evaluate(x_test, y_test)
# Out:
# 4/4 [==============================] - 3s 345ms/step - loss: 0.1475 - accuracy: 0.9115
# [0.1474912017583847, 0.9115325808525085]

# %%
# Show some predictions
y_test_hat = UNet.predict(x_test)

rand_ID = np.random.randint(0, len(x_test), 20) # Rand selection of images

print("RGB input -- Test set")
plt.figure(figsize=(18, 4))
for ind in range(20):
  plt.subplot(1, 20, ind+1)
  plt.imshow(x_test[rand_ID[ind]])
  plt.axis('off')
plt.tight_layout()
plt.show()

print("Mask output - Ground Truth -- Test set")
plt.figure(figsize=(18, 4))
for ind in range(20):
  plt.subplot(1, 20, ind+1)
  plt.imshow(y_test[rand_ID[ind]])
  plt.axis('off')
plt.tight_layout()
plt.show()

print("Prediction: binary -- Test set")
plt.figure(figsize=(18, 4))
for ind in range(20):
  plt.subplot(1, 20, ind+1)
  plt.imshow(y_test_hat[rand_ID[ind]].round())
  plt.axis('off')
plt.tight_layout()
plt.show()

print("Prediction: probability -- Test set")
plt.figure(figsize=(18, 4))
for ind in range(20):
  plt.subplot(1, 20, ind+1)
  plt.imshow(y_test_hat[rand_ID[ind]])
  plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# RGB input -- Test set
# Mask output - Ground Truth -- Test set
# Prediction: binary -- Test set
# Prediction: probability -- Test set

# %% [markdown]
# # Part 6: Yet another type of CNN

# %%
# Importa los dígitos MNIST
# == Q4 ==
# Revisa las celdas de esta sección.
# Explica por qué crees que, al importar las imágenes, las asignamos a una
# variable llamada 'y' (en vez de 'x' como lo hicimos en la tarea anterior).
from tensorflow.keras.datasets import mnist
(y_train, _), (y_test, _) = mnist.load_data() # puedes revisar la documentación
# de la base de datos MNIST

# Dividimos entre 255 para tener pixeles con valores entre 0 y 1.
y_train = y_train / 255.
y_test  = y_test  / 255.

# Hacemos reshape, ya que las CNN requieren conocer explícitamente el número de
# canales de las imágenes. 1 canal en caso de imágenes binarias y grises.
y_train = np.reshape(y_train, (y_train.shape[0], y_train.shape[1], y_train.shape[2], 1))
y_test  = np.reshape(y_test, (y_test.shape[0], y_test.shape[1], y_test.shape[2], 1))

print("Shapes")
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# Shapes
# y_train: (60000, 28, 28, 1)
# y_test: (10000, 28, 28, 1)

# %%
# == Q5 ==
# Aquí defino una funión. ¿Puedes explica qué es lo que hace?
from skimage.transform import resize

def noisy_resize(img):
  img = resize(img, (7, 7))
  for row in range(7):
    for col in range(7):
      if np.random.rand() > 0.9:
        img[row, col] = np.abs(img[row, col] - 1)
  return img

# %%
# Ahora sí genero x (señales de entrada)
x_train = np.array([noisy_resize(img) for img in y_train])
x_test  = np.array([noisy_resize(img) for img in y_test ])

print("Shapes")
print("x_train:", x_train.shape)
print("x_test:", x_test.shape)
# Out:
# Shapes
# x_train: (60000, 7, 7, 1)
# x_test: (10000, 7, 7, 1)

# %%
# Show a few examples of X
for ind, img in enumerate(x_test[:10]):
  plt.subplot(1, 10, ind+1)
  plt.imshow(img[:,:,0], cmap='gray')
  plt.axis('off')
plt.tight_layout()
plt.show()

# %%
# Create a CNN (Notice there is no InputLayer)
CNN = Sequential([
    Conv2D(32, 3, padding='same', activation='relu', input_shape=x_train.shape[1:]),
    Conv2D(32, 3, padding='same', activation='relu'),
    UpSampling2D(),

    Conv2D(32, 3, padding='same', activation='relu'),
    Conv2D(32, 3, padding='same', activation='relu'),
    UpSampling2D(),

    Conv2D(32, 3, padding='same', activation='relu'),
    Conv2D(1, 3, padding='same', activation='sigmoid'),
])

CNN.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 7, 7, 32)          320
#
#  conv2d_7 (Conv2D)           (None, 7, 7, 32)          9248
#
#  up_sampling2d_2 (UpSampling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 32)        9248
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 32)        9248
#
#  up_sampling2d_3 (UpSampling  (None, 28, 28, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 32)        9248
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 37,601
# Trainable params: 37,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile and train
CNN.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['binary_accuracy'])
history = CNN.fit(x=x_train, y=y_train, batch_size=64, epochs=20, validation_split=0.1)
# Out:
# Epoch 1/20
# 844/844 [==============================] - 11s 12ms/step - loss: 0.3595 - binary_accuracy: 0.8047 - val_loss: 0.2411 - val_binary_accuracy: 0.7884
# Epoch 2/20
# 844/844 [==============================] - 10s 12ms/step - loss: 0.2167 - binary_accuracy: 0.7840 - val_loss: 0.2010 - val_binary_accuracy: 0.7887
# Epoch 3/20
# 844/844 [==============================] - 10s 12ms/step - loss: 0.1903 - binary_accuracy: 0.7905 - val_loss: 0.1889 - val_binary_accuracy: 0.7843
# Epoch 4/20
# 844/844 [==============================] - 10s 12ms/step - loss: 0.1790 - binary_accuracy: 0.7933 - val_loss: 0.1736 - val_binary_accuracy: 0.7933
# Epoch 5/20
# 844/844 [==============================] - 10s 11ms/step - loss: 0.1709 - binary_accuracy: 0.7951 - val_loss: 0.1675 - val_binary_accuracy: 0.7994
# Epoch 6/20
# 844/844 [==============================] - 10s 12ms/step - loss: 0.1644 - binary_accuracy: 0.7967 - val_loss: 0.1604 - val_binary_accuracy: 0.7965
# Epoch 7/20
# 844/844 [==============================] - 10s 11ms/step - loss: 0.1588 - binary_accuracy: 0.7982 - val_loss: 0.1568 - val_binary_accuracy: 0.8023
# Epoch 8/20
# 844/844 [==============================] - 10s 12ms/step - loss: 0.1543 - binary_accuracy: 0.7995 - val_loss: 0.1507 - val_binary_accuracy: 0.8004
# Epoch 9/20
# 844/844 [==============================] - 10s 12ms/step - loss: 0.1507 - binary_accuracy: 0.8005 - val_loss: 0.1548 - val_binary_accuracy: 0.8060
# Epoch 10/20
# 844/844 [==============================] - 10s 12ms/step - loss: 0.1468 - binary_accuracy: 0.8015 - val_loss: 0.1434 - val_binary_accuracy: 0.8034
# Epoch 11/20
# 844/844 [==============================] - 10s 12ms/step - loss: 0.1440 - binary_accuracy: 0.8023 - val_loss: 0.1412 - val_binary_accuracy: 0.8014
# Epoch 12/20
# 844/844 [==============================] - 10s 11ms/step - loss: 0.1409 - binary_accuracy: 0.8031 - val_loss: 0.1384 - val_binary_accuracy: 0.8058
# Epoch 13/20
# 844/844 [==============================] - 10s 11ms/step - loss: 0.1384 - binary_accuracy: 0.8037 - val_loss: 0.1358 - val_binary_accuracy: 0.8031
# Epoch 14/20
# 844/844 [==============================] - 10s 12ms/step - loss: 0.1362 - binary_accuracy: 0.8042 - val_loss: 0.1346 - val_binary_accuracy: 0.8069
# Epoch 15/20
# 844/844 [==============================] - 10s 12ms/step - loss: 0.1338 - binary_accuracy: 0.8048 - val_loss: 0.1313 - val_binary_accuracy: 0.8051
# Epoch 16/20
# 844/844 [==============================] - 10s 12ms/step - loss: 0.1317 - binary_accuracy: 0.8053 - val_loss: 0.1318 - val_binary_accuracy: 0.8076
# Epoch 17/20
# 844/844 [==============================] - 10s 12ms/step - loss: 0.1299 - binary_accuracy: 0.8057 - val_loss: 0.1286 - val_binary_accuracy: 0.8052
# Epoch 18/20
# 844/844 [==============================] - 10s 12ms/step - loss: 0.1282 - binary_accuracy: 0.8060 - val_loss: 0.1288 - val_binary_accuracy: 0.8082
# Epoch 19/20
# 844/844 [==============================] - 10s 12ms/step - loss: 0.1269 - binary_accuracy: 0.8063 - val_loss: 0.1259 - val_binary_accuracy: 0.8059
# Epoch 20/20
# 844/844 [==============================] - 10s 12ms/step - loss: 0.1255 - binary_accuracy: 0.8066 - val_loss: 0.1249 - val_binary_accuracy: 0.8060

# %%
# Predict on the test set, and plot a few examples
y_test_hat = CNN.predict(x_test[:10])

print("Noisy")
for ind, img in enumerate(x_test[:10]):
  plt.subplot(1, 10, ind+1)
  plt.imshow(img[:,:,0], cmap='gray')
  plt.axis('off')
plt.show()

print("Predicted")
for ind, img in enumerate(y_test_hat):
  plt.subplot(1, 10, ind+1)
  plt.imshow(img[:,:,0], cmap='gray')
  plt.axis('off')
plt.show()

print("Original")
for ind, img in enumerate(y_test[:10]):
  plt.subplot(1, 10, ind+1)
  plt.imshow(img[:,:,0], cmap='gray')
  plt.axis('off')
plt.show()
# Out:
# Noisy
# Predicted
# Original

# %%
# == Q6 ==
# ¿Qué problema está resolviendo esta red?

# == Q7 ==
# ¿Puedes mejorar el modelo para aumentar la exactitud a más de 0.95?
# Reporta el modelo resultante.
